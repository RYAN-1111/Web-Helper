# %% [markdown]
# NLTK (Natural Language Toolkit) is a Python library for text processing and natural language tasks. It provides functionalities for text summarization. Using NLTK, you can tokenize the text into words or sentences, remove stopwords, calculate word frequencies, assign scores to sentences, and generate a summary by selecting top-ranked sentences. NLTK's summarization capabilities allow you to condense a text into a shorter version that captures the essential information.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import pandas as pd

nltk.download('punkt')
nltk.download('stopwords')

# Read the dataset file
dataset_path = 'amazonreviews.tsv'
df = pd.read_csv(dataset_path, delimiter='\t')

# Extract the text from a specific column in the DataFrame
text_column = 'text'  # Replace with the actual column name in your dataset

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    text = row['review']

    # Tokenize the text into sentences
    sentences = sent_tokenize(text)

    # Tokenize the text into words
    words = word_tokenize(text.lower())

    # Remove stopwords from the words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalnum() and word not in stop_words]

    # Calculate the frequency of each word
    word_freq = nltk.FreqDist(words)

    # Assign scores to sentences based on the frequency of words they contain
    sentence_scores = {}
    for sentence in sentences:
        for word in word_tokenize(sentence.lower()):
            if word in word_freq:
                if sentence not in sentence_scores:
                    sentence_scores[sentence] = word_freq[word]
                else:
                    sentence_scores[sentence] += word_freq[word]

    # Set the desired number of sentences for the summary
    num_sentences = 3

    # Get the top N sentences with the highest scores
    top_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:num_sentences]

    # Concatenate the top sentences to form the summary
    summary = ' '.join(top_sentences)

    # Print the summary for the current row
    print(f"Summary for Row {index + 1}: {summary}")
    print()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ryanr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ryanr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Summary for Row 1: I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It paints the senery in your mind so well I would recomend it even to people who hate vid. It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras.
#
# ...
